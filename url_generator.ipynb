# %% [markdown]
# # URL GENERATION

# %% [markdown]
# ### IMPORTS

# %%
import pandas as pd
import re
import numpy as np
import json

# %% [markdown]
# ### READING IN THE DATA

# %%
data = pd.read_excel('fede_data.xlsx')

# %%
data = data[data.year != "rik"]
data = data[data.year.astype(int) >= 2000]
data
# Out:
#       year                                     category  \
# 1     2019  Best Latin Rock, Urban or Alternative Album
# 3     2010              Best Musical Album for Children
# 5     2007                            Best Reggae Album
# 7     2019                            Best Reggae Album
# 8     2017                            Best Reggae Album
# ...    ...                                          ...
# 6318  2019              Producer of the Year, Classical
# 6319  2019              Producer of the Year, Classical
# 6320  2019          Producer of the Year, Non-Classical
# 6321  2019          Producer of the Year, Non-Classical
# 6322  2019          Producer of the Year, Non-Classical
#
#                         nominee  \
# 1                        Aztlán
# 3                   Family Time
# 5           Love Is My Religion
# 7               Rebellion Rises
# 8                  Ziggy Marley
# ...                         ...
# 6318    Dirk Sobotka (producer)
# 6319  Judith Sherman (producer)
# 6320          Pharrell Williams
# 6321      Kanye West (producer)
# 6322     Linda Perry (producer)
#
#                                                 workers  winner  url
# 1     Zoé (artist/producer), Phil Vinall (producer),...    True  NaN
# 3     Ziggy Marley (producer/artist), Don Was (produ...    True  NaN
# 5     Ziggy Marley (artist), Marc Moreau (engineer/m...    True  NaN
# 7                                 Ziggy Marley (artist)   False  NaN
# 8                                          Ziggy Marley    True  NaN
# ...                                                 ...     ...  ...
# 6318                                                NaN   False  NaN
# 6319                                                NaN   False  NaN
# 6320                                                NaN    True  NaN
# 6321                                                NaN   False  NaN
# 6322                                                NaN   False  NaN
#
# [3461 rows x 6 columns]

# %% [markdown]
# ### DATA CLEANING

# %%
data["url"] = data.url.fillna(0) # change NaNs to zero

# %%
data["album"] = [True if re.match(r".*Album.*",x) else False for x in data.category]
data = data[data.album == True].drop("album",axis = 1).reset_index(drop = True) # keep only the albums
data = data[~data.category.str.contains("Classical")].reset_index(drop = True) # remove classical music
data.workers = data.workers.astype(str) # changing column type
data.head(10)
# Out:
#    year                                           category  \
# 0  2019        Best Latin Rock, Urban or Alternative Album
# 1  2010                    Best Musical Album for Children
# 2  2007                                  Best Reggae Album
# 3  2019                                  Best Reggae Album
# 4  2017                                  Best Reggae Album
# 5  2007                        Best Electronic/Dance Album
# 6  2018            Best Contemporary Christian Music Album
# 7  2019            Best Contemporary Christian Music Album
# 8  2005  Best Compilation Soundtrack Album for a Motion...
# 9  2010                                 Best Country Album
#
#                               nominee  \
# 0                              Aztlán
# 1                         Family Time
# 2                 Love Is My Religion
# 3                     Rebellion Rises
# 4                        Ziggy Marley
# 5                          The Garden
# 6                       Chain Breaker
# 7  Survivor: Live from Harding Prison
# 8                        Garden State
# 9                     The Foundation.
#
#                                              workers  winner url
# 0  Zoé (artist/producer), Phil Vinall (producer),...    True   0
# 1  Ziggy Marley (producer/artist), Don Was (produ...    True   0
# 2  Ziggy Marley (artist), Marc Moreau (engineer/m...    True   0
# 3                              Ziggy Marley (artist)   False   0
# 4                                       Ziggy Marley    True   0
# 5                                             Zero 7   False   0
# 6                             Zach Williams (artist)    True   0
# 7                                      Zach Williams   False   0
# 8                  Zach Braff (compilation producer)    True   0
# 9                                     Zac Brown Band   False   0

# %%
data.shape
# Out:
# (1500, 6)

# %%
# Establishing whether the URLs are strange cases, which are then be generated by hand
data["strange_cases"] = data.workers.apply(lambda x: True if (not re.search(r"\)",x) and re.search(r",",x)) else False)
data = data.sort_values("year").reset_index(drop = True)
# Out:
#       year                                     category  \
# 0     2019  Best Latin Rock, Urban or Alternative Album
# 1     2010              Best Musical Album for Children
# 2     2007                            Best Reggae Album
# 3     2019                            Best Reggae Album
# 4     2017                            Best Reggae Album
# ...    ...                                          ...
# 1495  2012                       Best Spoken Word Album
# 1496  2013                  Best Pop Instrumental Album
# 1497  2013                       Best Spoken Word Album
# 1498  2015               Best Large Jazz Ensemble Album
# 1499  2015                        Best Latin Jazz Album
#
#                                              nominee  \
# 0                                             Aztlán
# 1                                        Family Time
# 2                                Love Is My Religion
# 3                                    Rebellion Rises
# 4                                       Ziggy Marley
# ...                                              ...
# 1495  Fab Fan Memories - The Beatles Bond (Various).
# 1496               Rumbadoodle (Artist: Arun Shenoy)
# 1497                American Grown (Michelle Obama).
# 1498                     The L.A. Treasures Project.
# 1499                     The Pedrito Martinez Group.
#
#                                                 workers  winner url  \
# 0     Zoé (artist/producer), Phil Vinall (producer),...    True   0
# 1     Ziggy Marley (producer/artist), Don Was (produ...    True   0
# 2     Ziggy Marley (artist), Marc Moreau (engineer/m...    True   0
# 3                                 Ziggy Marley (artist)   False   0
# 4                                          Ziggy Marley    True   0
# ...                                                 ...     ...  ..
# 1495                                                nan   False   0
# 1496                                                nan   False   0
# 1497                                                nan   False   0
# 1498                                                nan   False   0
# 1499                                                nan   False   0
#
#       strange_cases
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1495          False
# 1496          False
# 1497          False
# 1498          False
# 1499          False
#
# [1500 rows x 7 columns]

# %% [markdown]
# Function to perform some basic cleaning the name of the artist and the name of the album

# %%
def clean(s):
    #Regex cleaning
    s = re.sub(r"^\s|\s$", "", s) # replace spaces at the start and at the end of the string
    s = re.sub(r"\s","-",s) # replace normal spaces with dashes
    s = re.sub(r"\.","",s) #remove dots
    s = re.sub(r"&","and",s) # replace & with "and"
    s = re.sub(r"[áàâäāãåăąÀÁÂÄĀÃÅĂĄ]","a",s) # Replace accents
    s = re.sub(r"[éèêëēėęĚĒÈÉÊËĖĘ]","e",s)
    s = re.sub(r"[íìîïīįīĨÌÍÎÏĪĮ]","i",s)
    s = re.sub(r"[óòôöōõøőÓÒÔÖŌÕØŐ]","o",s)
    s = re.sub(r"[úùûüūųÚÙÛÜŪŲ]","u",s)
    s = re.sub(r"[çĉćċčÇĈĆĊČ]","c",s)
    s = re.sub(r"[ñńňņŉŋÑŃŇŅŉŊ]","n",s)
    s = s.lower() #lower case 

    # deal with particular cases
    if s == "ti":
        s = "t_i"
    elif s == "nati-cano's-mariachi-los-camperos":
        s = "mariachi-los-camperos-de-nati-cano"
    elif s == "george-carlin-it's-bad-for-ya!":
        s = "george-carlin"
    elif s == "ferdinand-'jelly-roll'-morton":
        s = "jelly-roll-morton"
    elif s == "":
        s = ""
    s = re.sub(r"['!:]","",s) # remove extra punctuation

    if s == "kalani-pea":
        s = "kalani-pe'a"
    
    
    return s

# %%
def clean_total(l):

    """
    Parameters: l --> list of artist names to be cleaned 
    Output: The function looks for the string "(artist)" and all its variations, then takes the 
            name in front of the string if there is an artist, otherwise it returns the whole name
            passed through the clean() function
    """

    new_artist = []

    # FIRST ROUND OF CLEANING
    for i in l:
        if re.search(r".*\(.*artist.*\).*",str(i)): 
            name = " ".join((re.findall(r".*(?=\s\(.*artist.*\))",str(i))))
            if re.search(r"\),",name): # dealing with cases where the artist is not in the front of the string
                #print("hello")
                name = " ".join(re.findall(r"(?<=,)[^,]+$",name)) # take everything after the comma
                name = clean(name)
                new_artist.append(name)
            else:
                name = clean(name)
                new_artist.append(name)

        elif re.search(r"\(",i):
            name = " ".join(re.findall(r"^.*?(?<=\()",i))
            name = re.sub(r"\(","",name)
            name = clean(name)
            new_artist.append(name)
        else:
            name = clean(i)
            new_artist.append(name)
    return new_artist
# Out:
# ['duke-ellington']

# %% [markdown]
# Cleaning the nominee name and the album name

# %%
data["workers_clean"] = clean_total(data.workers)
data["nominee_semiclean"] = data.nominee.astype(str).apply(lambda x: clean(x)).tolist()

# %% [markdown]
# ### URL generation and additional cleaning

# %%
data["url_final"] = ["https://rateyourmusic.com/release/album/" + data.workers_clean[i] + "/" + data.nominee_semiclean[i] + "/" if data.url[i] == 0 else data.url[i] for i in range(len(data))]
data = data[data.url != "delete"]

# %%
data = data.drop(index = data[(data.duplicated(subset = ["year","nominee"], keep = False)) & (data.winner == False)].index)

# %% [markdown]
# Saving the files

# %%
list_urls = data.url_final.tolist()
with open("list_urls3.json","w") as f:
    json.dump(list_urls,f)
